# %% [markdown]
# # CEDE Preprocessing
# The data from CEDE is collected and filtered so that it can be joined to the main table.
#
# ### TO DO:
# * on final table rename columns so they make sense

# %%
import pandas as pd
import numpy as np

# %%
# read data 
agriculture=pd.read_stata('RAW DATA\PANEL_AGRICULTURA_Y_TIERRA(2023).dta')
violence=pd.read_stata('RAW DATA\PANEL_CONFLICTO_Y_VIOLENCIA(2022).dta')
chars=pd.read_stata('RAW DATA\PANEL_CARACTERISTICAS_GENERALES(2022).dta')
gov=pd.read_stata('RAW DATA\PANEL_BUEN_GOBIERNO(2023).dta')

# %% [markdown]
# ## 1. Cofee cultivation & production
# * Only coverage 2007-2022
# * Can one assume NaN at this level is 0?

# %%
# keep only relevant columns 
coffee=agriculture[['codmpio','ano','ac_cafe','p_cafe']]

# drop observations with no information on municipality or year 
coffee=coffee.dropna(subset=['codmpio','ano'])

# %%
# check how many observations there are each year
coffee.groupby(by='ano').count()
# Out:
#       codmpio  ac_cafe  p_cafe
# ano
# 2003     1106        0       0
# 2004     1106        0       0
# 2005     1106        0       0
# 2006     1106        0       0
# 2007     1110      591     591
# 2008     1110      598     598
# 2009     1110      610     610
# 2010     1107      618     618
# 2011     1107      625     625
# 2012     1109      600     600
# 2013     1110      596     596
# 2014     1110      595     595
# 2015     1110      595     595
# 2016     1111      598     598
# 2017     1112      600     600
# 2018     1114      602     602
# 2019     1113      619     619
# 2020     1110      625     625
# 2021     1110      631     631
# 2022     1104      631     631

# %%
# since no observation before 2007, drop those years 
coffee=coffee[coffee['ano']>2006]
# fill rest of missings with 0
    # TO DO: Check if this makes sense 
coffee=coffee.fillna(0)

# %%
coffee.head(5)
# Out:
#    codmpio   ano  ac_cafe      p_cafe
# 4   5001.0  2007   1027.0  821.599976
# 5   5001.0  2008   1027.0  821.599976
# 6   5001.0  2009   1027.0  800.000000
# 7   5001.0  2010   1078.0  862.400024
# 8   5001.0  2011   1058.0  846.400024

# %% [markdown]
# ## 2. Coca cultivation
# ### TO DO:
# * Validate with my data + with dube & Vargas so one get as much coverage as possible
# * Find out what is each variable --> For now H_coca

# %%
coca=violence[['codmpio','ano','coca','H_Coca_menor3','H_Coca_mayor3',
          'H_coca','lotes_coca','P_Coca_menor3','P_Coca_mayor3']]

# %%
# check how many observations there are each year
coca.groupby(by='ano').count()
# Out:
#         codmpio  coca  H_Coca_menor3  H_Coca_mayor3  H_coca  lotes_coca  \
# ano
# 1993.0     1124     0              0              0       0           0
# 1994.0     1123     0              0              0       0           0
# 1995.0     1125     0              0              0       0           0
# 1996.0     1124     0              0              0       0           0
# 1997.0     1124     0              0              0       0           0
# 1998.0     1123     0              0              0       0           0
# 1999.0     1124    91              0              0      91           0
# 2000.0     1124   178              0              0     178         191
# 2001.0     1125   164            160            134     164         166
# 2002.0     1125   168            165            125     168         169
# 2003.0     1125   189            186            186     189         189
# 2004.0     1125   190            186            128     190         190
# 2005.0     1125   190            186            126     190         191
# 2006.0     1125   199            195            123     199         200
# 2007.0     1125   195            190            126     195         195
# 2008.0     1125   206            203            114     206         209
# 2009.0     1125   217            218             96     217         218
# 2010.0     1125   207              0              0     207         208
# 2011.0     1124   205              0              0     205         212
# 2012.0     1125   212              0              0     212         207
# 2013.0     1125   203              0              0     203         206
# 2014.0     1124   204              0              0     204         207
# 2015.0     1124   192              0              0     192           0
# 2016.0     1124   183              0              0     183           0
# 2017.0     1123   186              0              0     186           0
# 2018.0     1124   187              0              0     187           0
# 2019.0     1124   176              0              0     176           0
# 2020.0     1112   172              0              0     172           0
# 2021.0     1119   181              0              0     181           0
#
#         P_Coca_menor3  P_Coca_mayor3
# ano
# 1993.0              0              0
# 1994.0              0              0
# 1995.0              0              0
# 1996.0              0              0
# 1997.0              0              0
# 1998.0              0              0
# 1999.0              0              0
# 2000.0              0              0
# 2001.0            160            134
# 2002.0            165            125
# 2003.0            186            186
# 2004.0            186            128
# 2005.0            186            126
# 2006.0            195            123
# 2007.0            190            126
# 2008.0            203            114
# 2009.0            218             96
# 2010.0              0              0
# 2011.0              0              0
# 2012.0              0              0
# 2013.0              0              0
# 2014.0              0              0
# 2015.0              0              0
# 2016.0              0              0
# 2017.0              0              0
# 2018.0              0              0
# 2019.0              0              0
# 2020.0              0              0
# 2021.0              0              0

# %%
# drop observations with no information on municipality or year 
coca=coca.dropna(subset=['codmpio','ano'])

# keep only relevant columns 
    # TO DO: See if col choice makes sense 
coca=coca[['codmpio','ano','H_coca']]
# fill rest of missings with 0
    # TO DO: Check if this makes sense 
coca=coca.fillna(0)

# %%
coca.head(5)
# Out:
#    codmpio     ano   H_coca
# 0   5107.0  2021.0   363.09
# 1   5120.0  2021.0  1869.62
# 2   5134.0  2021.0   326.09
# 3   5234.0  2021.0     0.00
# 4   5250.0  2021.0  1152.82

# %% [markdown]
# ## 3. Population
# This information was inputed since there is not registration system as in germany.

# %%
# keep only relevant columns 
pop=chars[['codmpio','ano','pobl_tot']]

# drop observations with no information on municipality or year 
pop=pop.dropna(subset=['codmpio','ano'])

# %%
# check how many observations there are each year
pop.groupby(by='ano').count()
    #all seem to be complete
# Out:
#         codmpio  pobl_tot
# ano
# 1993.0     1122      1122
# 1994.0     1122      1122
# 1995.0     1122      1122
# 1996.0     1122      1122
# 1997.0     1122      1122
# 1998.0     1122      1122
# 1999.0     1122      1122
# 2000.0     1122      1122
# 2001.0     1122      1122
# 2002.0     1122      1122
# 2003.0     1122      1122
# 2004.0     1122      1122
# 2005.0     1122      1122
# 2006.0     1122      1122
# 2007.0     1122      1122
# 2008.0     1122      1122
# 2009.0     1122      1122
# 2010.0     1122      1122
# 2011.0     1122      1122
# 2012.0     1122      1122
# 2013.0     1122      1122
# 2014.0     1122      1122
# 2015.0     1122      1122
# 2016.0     1122      1122
# 2017.0     1122      1122
# 2018.0     1122      1122
# 2019.0     1121      1121
# 2020.0     1121      1121
# 2021.0     1121      1121

# %%
pop.replace(0, np.nan, inplace=True)

# %%
pop[pop['pobl_tot'].isna()]
# Out:
#        codmpio     ano  pobl_tot
# 1856    5390.0  1993.0       NaN
# 1857    5390.0  1994.0       NaN
# 1858    5390.0  1995.0       NaN
# 1859    5390.0  1996.0       NaN
# 4379   13030.0  1993.0       NaN
# ...        ...     ...       ...
# 31755  91536.0  1993.0       NaN
# 31756  91536.0  1994.0       NaN
# 31757  91536.0  1995.0       NaN
# 31758  91536.0  1996.0       NaN
# 31759  91536.0  1997.0       NaN
#
# [335 rows x 3 columns]

# %%
# compute log 
    #add 1 to avoid going to infinite
pop['lpop']=np.log((pop['pobl_tot']+1)/1000000)

# %%
pop.head(5)
# Out:
#    codmpio     ano   pobl_tot      lpop
# 0   5001.0  1993.0  1793491.0  0.584165
# 1   5001.0  1994.0  1832197.0  0.605516
# 2   5001.0  1995.0  1872241.0  0.627137
# 3   5001.0  1996.0  1912860.0  0.648600
# 4   5001.0  1997.0  1953293.0  0.669517

# %% [markdown]
# ## 4. Capital Revenue
# Unclear if this is helpful. Not helpful in the we use TerriData.
#
# ### TO DO:
# * Get documentation of CEDE

# %%
# keep only relevant columns 
gov=gov[['codmpio','ano','y_cap_regalias','IGA_regalias']]

# drop observations with no information on municipality or year 
gov=gov.dropna(subset=['codmpio','ano'])

# %%
# check how many observations there are each year
gov.groupby(by='ano').count()
    # y cap regalias seems better but still unclear if this is what we need
# Out:
#         codmpio  y_cap_regalias  IGA_regalias
# ano
# 1984.0     1098            1098             0
# 1985.0     1098            1098             0
# 1986.0     1098            1098             0
# 1987.0     1098            1098             0
# 1988.0     1098            1098             0
# 1989.0     1098            1098             0
# 1990.0     1098            1098             0
# 1991.0     1098            1098             0
# 1992.0     1098            1098             0
# 1993.0     1122            1098             0
# 1994.0     1122            1098             0
# 1995.0     1122            1098             0
# 1996.0     1122            1098             0
# 1997.0     1122            1098             0
# 1998.0     1122            1098             0
# 1999.0     1122            1098             0
# 2000.0     1122            1097             0
# 2001.0     1122            1097             0
# 2002.0     1122            1097             0
# 2003.0     1122            1097             0
# 2004.0     1122            1097             0
# 2005.0     1122            1097             0
# 2006.0     1122            1097             0
# 2007.0     1122            1097             0
# 2008.0     1122            1100             0
# 2009.0     1122            1101             0
# 2010.0     1123            1101             0
# 2011.0     1123            1086             0
# 2012.0     1123            1101             0
# 2013.0     1122            1101          1101
# 2014.0     1122            1101          1101
# 2015.0     1122            1101          1101
# 2016.0     1122            1101          1101
# 2017.0     1122            1101             0
# 2018.0     1122            1101             0
# 2019.0     1121            1101             0
# 2020.0     1121            1101             0
# 2021.0     1121            1102             0
# 2022.0     1121            1102             0

# %%
# get column I decided
    # TBD if it makes sense 
gov=gov[['codmpio','ano','y_cap_regalias']]
# fill rest of missings with 0
    # TO DO: Check if this makes sense 
gov=gov.fillna(0)

# %%
gov.head(5)
# Out:
#    codmpio     ano  y_cap_regalias
# 0   5001.0  1984.0             0.0
# 1   5001.0  1985.0             0.0
# 2   5001.0  1986.0             0.0
# 3   5001.0  1987.0             0.0
# 4   5001.0  1988.0             0.0

# %% [markdown]
# # JOIN TABLES

# %%
cede=coffee.merge(coca, how='outer', on=['codmpio','ano'],validate='1:1')
cede=cede.merge(pop, how='outer', on=['codmpio','ano'],validate='1:1')
cede=cede.merge(gov, how='outer', on=['codmpio','ano'],validate='1:1')

# %%
# rename columns 
rename_dict={'codmpio':'muncode','ano': 'year'}
cede=cede.rename(columns=rename_dict)
cede
# Out:
#        muncode    year  ac_cafe      p_cafe  H_coca   pobl_tot      lpop  \
# 0       5001.0  2007.0   1027.0  821.599976     0.0  2265244.0  0.817683
# 1       5001.0  2008.0   1027.0  821.599976     0.0  2291378.0  0.829154
# 2       5001.0  2009.0   1027.0  800.000000     0.0  2317336.0  0.840419
# 3       5001.0  2010.0   1078.0  862.400024     0.0  2343049.0  0.851453
# 4       5001.0  2011.0   1058.0  846.400024     0.0  2368282.0  0.862165
# ...        ...     ...      ...         ...     ...        ...       ...
# 43605  99773.0  1988.0      NaN         NaN     NaN        NaN       NaN
# 43606  99773.0  1989.0      NaN         NaN     NaN        NaN       NaN
# 43607  99773.0  1990.0      NaN         NaN     NaN        NaN       NaN
# 43608  99773.0  1991.0      NaN         NaN     NaN        NaN       NaN
# 43609  99773.0  1992.0      NaN         NaN     NaN        NaN       NaN
#
#        y_cap_regalias
# 0              33.031
# 1              50.457
# 2             126.854
# 3              47.348
# 4              50.911
# ...               ...
# 43605           0.000
# 43606           0.000
# 43607           0.000
# 43608           0.000
# 43609           0.000
#
# [43610 rows x 8 columns]

# %%
cede.to_csv('CEDE_data.csv')
